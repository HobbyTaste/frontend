# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pmdarima as pm
from tqdm import tqdm
from itertools import product

import sys; sys.path.insert(0, '..')
from models.VAR.preprocessor import Preprocessor
from models.VAR.metrics import root_mean_squared_error, mean_absolute_percentage_error

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.api import VAR
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %matplotlib inline
sns.set(font_scale=1.5)

import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
# Out:
# /home/denis/anaconda3/envs/mipt-stats/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /home/denis/anaconda3/envs/mipt-stats/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [raw]
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Будем рассматривать два дата-сета: апериодический(информация о стоимости акций на американской бирже NASDAQ) и периодический(с ярко выраженной сезонностью и трендом) датасет с данными о ежемесячном производстве электричества.

# %% [raw]
# DATA_PATH_APERIODIC = '/content/drive/My Drive/HobbyTaste/data/nasdaq100_padding.csv'
# DATA_PATH_PERIODIC = '/content/drive/My Drive/HobbyTaste/data/Electric_Production.csv'

# %%
DATA_PATH_APERIODIC = '../data/nasdaq100_padding.csv'
DATA_PATH_PERIODIC = '../data/electric_production.csv'

# %%
nasdaq_df = pd.read_csv(DATA_PATH_APERIODIC)
electric_production_df = pd.read_csv(DATA_PATH_PERIODIC)
D_size = 3

# %% [markdown]
# Посмотрим на данные, используя класс Preprocessor

# %%
nasdaq_preproc_data = Preprocessor(
    data=nasdaq_df.iloc[:40000, :].values,
    D_size=3
)
elec_prod_preproc = Preprocessor(
    data=electric_production_df.iloc[:, 1].values.reshape(-1, 1),
    D_size=1
)

# %%
nasdaq_preproc_data.train_test_split(train_size=39700)
nasdaq_preproc_data.plot_data(titles=nasdaq_df.columns[:5])
# Out:
# 100%|██████████| 269/269 [00:00<00:00, 17285.37it/s]

# %%
elec_prod_preproc.train_test_split(train_size=300)
elec_prod_preproc.plot_data(titles=['Electric Production'])
# Out:
# 100%|██████████| 66/66 [00:00<00:00, 22919.69it/s]

# %% [markdown]
# Воспользуемся моделью VAR(p). Это простая регрессия на последние p компонент временного ряда. Хорошие предсказания без предварительной обработки ряда вряд ли получится получить, т.к. модель совсем не учитывает особенности ряда. Именно поэтому ее можно хорошо применять, например, к стационарным рядам, тем не менее, попробуем VAR(p) на исходных данных.

# %%
model = VAR(nasdaq_preproc_data.train_data)

# %% [markdown]
# Посмотрим на разные значения p, выберем подходящее исходя из критериев информативности.

# %%
model_fit = model.fit(maxlags=50, ic='aic')

# %%
p = model_fit.k_ar

# %%
predictions = model_fit.forecast(nasdaq_preproc_data.train_data[-p:], steps=300)
for i in np.arange(D_size):     
    plt.figure(figsize=(15, 10))
    plt.title(nasdaq_df.columns[i]) 
    plt.plot(predictions[:,i], 
             label='predictions')
    plt.plot(nasdaq_preproc_data.test_data[:,i], 
             label='test')
    plt.legend()
    plt.show()

# %%
model = AR(elec_prod_preproc.train_data)
# Out:
# /home/denis/anaconda3/envs/mipt-stats/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)

# %%
model_fit = model.fit(maxlags=30, ic='aic', )
# Out:
# /home/denis/anaconda3/envs/mipt-stats/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)

# %%
predictions = model_fit.predict(start=elec_prod_preproc.train_size, 
                                end=elec_prod_preproc.train_size+\
                                elec_prod_preproc.test_size)

# %%
plt.figure(figsize=(12, 8))
plt.title('Electric Production')
plt.plot(predictions, label='predictions')
plt.plot(elec_prod_preproc.test_data, label='test')
plt.legend()
plt.show()

# %% [markdown]
# Как видим, т.к. я указал максимальное количество лагов=30, модель смогла найти ежемесячные закономерности и мы получили неплохой результат на тестовой выборке, что и видно на графике.

# %% [markdown]
# Однако без обработки данных и их исследования, модель VAR оказывается вообще говоря малоэффективной, для апериодического ряда, например, угадывается лишь некотрый тренд.

# %% [markdown]
# Посмотрим на модель SARIMAX(ARIMA с сезонностью).

# %%
elec_prod_preproc.train_data = elec_prod_preproc.train_data.reshape(-1)

# %% [markdown]
# Подберем оптимальные параметры для модели SARIMAX, используя информационный критерий Акаике.

# %%
model = pm.auto_arima(elec_prod_preproc.train_data, 
                      start_p=1, 
                      start_q=1,
                      test='adf',
                      m=12,
                      max_p=7,
                      max_q=7,
                      seasonal=True,
                      error_action='ignore', 
                      trace=True)
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=1285.126, BIC=1307.104, Fit time=1.890 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=1470.224, BIC=1477.550, Fit time=0.034 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=1335.653, BIC=1350.305, Fit time=0.325 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=1310.141, BIC=1324.793, Fit time=0.326 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=1283.548, BIC=1301.863, Fit time=0.608 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=1376.662, BIC=1391.314, Fit time=0.158 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=1284.820, BIC=1306.798, Fit time=1.825 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=1284.833, BIC=1310.473, Fit time=2.609 seconds
# /home/denis/anaconda3/envs/mipt-stats/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/denis/anaconda3/envs/mipt-stats/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=1285.670, BIC=1307.648, Fit time=1.479 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=1282.373, BIC=1297.025, Fit time=0.412 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=1283.794, BIC=1302.109, Fit time=0.464 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=1374.756, BIC=1385.745, Fit time=0.070 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 2, 12); AIC=1283.397, BIC=1301.712, Fit time=0.911 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=1283.275, BIC=1305.253, Fit time=1.780 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=1407.883, BIC=1418.872, Fit time=0.244 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=1283.907, BIC=1302.222, Fit time=0.416 seconds
# Total fit time: 14.612 seconds

# %%
electric_production_predictions = model.predict(len(elec_prod_preproc.test_data))

# %%
plt.figure(figsize=(12, 8))
plt.title('Electric Production')
plt.plot(electric_production_predictions, label='predictions')
plt.plot(elec_prod_preproc.test_data, label='test')
plt.legend()
plt.show()

# %% [markdown]
# Как видими, графики визуально похожи, однако на пика достигается значительная разница. Значение метрики из-за этого скорее всего будет достаточно высоким.

# %% [markdown]
# Попробуем ARIMA для апериодического датасета. Рассмотрим акции компании APPLE.

# %%
apple_data_train = nasdaq_preproc_data.train_data[:, 1]
apple_data_test = nasdaq_preproc_data.test_data[:, 1]

# %% [markdown]
# Будем смотреть на логарифм исходных данных. Дальнейшее дифференцирование дает стационарный ряд(гипотеза о не стационарности отвергается). Аналогично, проведя поиск параметров, исходя из критерия информативности Акаике, я получил, что оптимальными являются order = (0, 1, 0), seasonal_order=(0, 0, 0, 12). Вообще говоря, мы получим предсказание константой.

# %%
model = SARIMAX(np.log(apple_data_train), order=(0, 1, 0), 
                seasonal_order=(0, 0, 0, 12)).fit()
# Out:
# /home/denis/anaconda3/envs/mipt-stats/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# Посмотрим на предсказания и 95% доверительный интервал.

# %%
apple_predictions = np.exp(model.forecast(len(apple_data_test)))
intervals = np.exp(model.get_forecast(len(apple_data_test)).conf_int())

# %%
plt.figure(figsize=(12, 8))
plt.title('AAPL')
plt.plot(apple_predictions, label='predictions')
plt.plot(apple_data_test, label='test')
plt.fill_between(np.arange(0, 300), intervals[:, 0], intervals[:, 1], 
                 color='green', alpha=0.3, label='conf int')
plt.legend()
plt.show()

# %% [markdown]
# Теперь посчитаем метрики для модели ARIMA для двух датасетов. Будем использовать RMSE и MAPE.

# %%
metrics_test = pd.DataFrame(
    [
        [root_mean_squared_error(apple_predictions, 
                                 apple_data_test),
         mean_absolute_percentage_error(apple_data_test, 
                                        apple_predictions)],
        [root_mean_squared_error(electric_production_predictions, 
                                 elec_prod_preproc.test_data),
         mean_absolute_percentage_error(elec_prod_preproc.test_data, 
                                        electric_production_predictions)]
    ], 
    index = ['NASDAQ, AAPL',
             'Electric Production',
    ], 
    columns=['RMSE', 'MAPE']
)

# %%
metrics_test
# Out:
#                          RMSE       MAPE
# NASDAQ, AAPL         0.162601   0.112152
# Electric Production  9.411286  12.973127

# %% [markdown]
# Для периодического датасета, с ярко выраженной сезонностью результаты оказываются хуже, чем для апериодического датасета. Предсказание константой, из-за маленького изменения цены на акции Apple оказывается достаточно эффективным. Возможно, это связано с недостаточно хорошим подбором параметров с моей стороны.
