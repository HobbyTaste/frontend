# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('data.xlsx')
data.head()
# Out:
#                                       Название Специальность      Телефон  \
# 0  Студия художественного творчества "ПАЛИТРА"     Рисование  79175367002
# 1          Школа рисования для взрослых Матита     Рисование  74993978111
# 2               Художественная школа «Дом ИЗО»     Рисование  79152554378
# 3             Школа Искусств Перотти на Динамо     Рисование  74959201280
# 4         Школа Искусств Перотти на Юго-Западе     Рисование  74959201278
#
#                    email                                             Сайт  \
# 0    izozavart@yandex.ru                           www.galleryart-mos.com
# 1     art-matita@mail.ru                       http://art-matita.ru/blog/
# 2         nitaso@mail.ru  http://domizo.ru/shkola-zhivopisi-dlya-vzroslih
# 3  info@perottischool.ru                    https://www.perottischool.ru/
# 4  info@perottischool.ru                    https://www.perottischool.ru/
#
#                             vk.com  \
# 0        https://vk.com/vserisujut
# ...

# %%
arr = data['Специальность']

# %%
arr.value_counts()
# Out:
# Большой теннис               32
# Футбол                       17
# Хоккей                       15
# Шахматы                      15
# Настольный теннис            13
# Танцы                        12
# Плавание                     12
# Бокс                         12
# Музыкальная школа            10
# Рисование                    10
# Лыжные гонки                  9
# Волейбол                      9
# Лёгкая атлетика               8
# Борьба                        5
# Художественная гимнастика     5
# Фехтование                    5
# Водное поло                   4
# Синхронное плавание           4
# Спортивная гимнастика         3
# Восточные единоборства        3
# Тяжёлая атлетика              3
# Гребля                        3
# Бокс, Борьба                  2
# Теннис                        2
# Самбо                         2
# Бадминтон                     2
# Дзюдо                         2
# Прыжки в воду                 2
# Пулевая стрельба              2
# ...
